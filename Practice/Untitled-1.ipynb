# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\pardis\Desktop\digikala\product.xlsx')
data.head(3)
data.columns
# Out:
# Index(['id', 'product_title_fa', 'product_title_en', 'url_code', 'title_alt',
#        'category_title_fa', 'category_keywords', 'brand_name_fa',
#        'brand_name_en', 'product_attributes'],
#       dtype='object')

# %%
# !pip show openpyxl
# Out:
# WARNING: Package(s) not found: openpyxl

# %%
import sys
print(f"Python executable: {sys.executable}")
print(f"Python path: {sys.prefix}")
# Out:
# Python executable: c:\Users\pardis\miniconda3\envs\queraEnv\python.exe
# Python path: c:\Users\pardis\miniconda3\envs\queraEnv

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
