# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\pardis\Desktop\Pandas\Internet Prices.csv')
df.head()
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "InternetPrice"
# 0         66.441395
# 1         60.590455
# 2         68.988824
# 3         35.827084
# 4         66.690222

# %%
df = df.sort_values(' "InternetPrice"' , ascending=False).head(10)
df
# Out:
#                     City                  "Region"  \
# 482               Al Ain    "Emirate of Abu Dhabi"
# 231  Bandar Seri Begawan   "Brunei-Muara District"
# 324            Anchorage                  "Alaska"
# 232                 Male             "Kaafu Atoll"
# 187               Harare                        ""
# 91             Abu Dhabi    "Emirate of Abu Dhabi"
# 479           Santa Rosa              "California"
# 486              Sharjah      "Emirate of Sharjah"
# 38                 Dubai        "Emirate of Dubai"
# 437        Santa Barbara              "California"
#
#                        "Country"   "InternetPrice"
# 482       "United Arab Emirates"        112.940326
# 231                     "Brunei"        111.427533
# 324   "United States of America"        109.553333
# 232                   "Maldives"        109.223301
# 187                   "Zimbabwe"        104.833333
# 91        "United Arab Emirates"        101.023925
# ...

# %%
sns.scatterplot(x=' "Country"' , y= ' "InternetPrice"' , data= df , hue=' "InternetPrice"' ,size= ' "InternetPrice"' )
# Out:
# <Axes: xlabel=' "Country"', ylabel=' "InternetPrice"'>
